# %% [markdown]
# ## imports

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import pyspark.sql.functions as F
import pyspark.sql.functions as f
from pyspark.sql import Window

# %% [markdown]
# ## utils

# %%
# %run ./utils

# %% [markdown]
# ## path_config

# %%
bronze_layer = {
  'sales_data' : '/Volumes/retail_forecasting/bronze_layer/sales_data/sales.csv',
  'holiday_data' : '/Volumes/retail_forecasting/bronze_layer/holiday_data/holidays_events.csv',
  'transcations_data' : '/Volumes/retail_forecasting/bronze_layer/transcations_data/transactions.csv',
  'oil_data' : '/Volumes/retail_forecasting/bronze_layer/oil_data/oil.csv',
  'stores_data' : '/Volumes/retail_forecasting/bronze_layer/stores_hierarchy_data/stores.csv',
}

silver_layer = {
  'modelling_data' : '/Volumes/retail_forecasting/silver_layer/modelling_data',
  }
  
gold_layer = {}
